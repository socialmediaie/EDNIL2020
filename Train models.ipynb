# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split

from sklearn.metrics import classification_report


import pandas as pd

from collections import Counter

from utils import transform_label, transform_probs, CLASS_MAP

# %%
df = pd.read_json("./data/processed/en/train.json", orient="records", lines=True)
df.head()
# Out:
#      docid                                             tokens  \
# 0    file1  [1, dead,, 18, hurt, in, explosion, at, natura...
# 1   file10  [4, killed, in, mishap., content:Abohar,, Febr...
# 2  file100  [Srinagar, gunfight, ends,, 2, Lashkar, men, k...
# 3  file101  [Magnitude, 6.5, earthquake, strikes, Nicaragu...
# 4  file102  [BSF, head, constable, killed, in, cross-borde...
#
#                                                 tags  \
# 0  [B-CASUALTIES-ARG, I-CASUALTIES-ARG, I-CASUALT...
# 1  [B-CASUALTIES-ARG, I-CASUALTIES-ARG, O, B-MAN_...
# 2  [B-PLACE-ARG, B-MAN_MADE_EVENT.SHOOT_OUT, O, B...
# 3  [O, B-MAGNITUDE-ARG, B-NATURAL_EVENT.EARTHQUAK...
# 4  [B-CASUALTIES-ARG, I-CASUALTIES-ARG, I-CASUALT...
#
#                                               labels
# 0          {'MAN_MADE_EVENT.INDUSTRIAL_ACCIDENT': 5}
# 1          {'MAN_MADE_EVENT.VEHICULAR_COLLISION': 3}
# 2  {'MAN_MADE_EVENT.SHOOT_OUT': 10, 'MAN_MADE_EVE...
# 3                    {'NATURAL_EVENT.EARTHQUAKE': 2}
# 4  {'MAN_MADE_EVENT.SHOOT_OUT': 10, 'MAN_MADE_EVE...

# %%
df.shape
# Out:
# (828, 4)

# %%
df_train, df_valid = train_test_split(df, test_size=0.10, random_state=42)

# %%
df_train.shape, df_valid.shape
# Out:
# ((745, 4), (83, 4))

# %%
Counter({"a": 5}) + Counter({"a": 2, "b": 3})
# Out:
# Counter({'a': 7, 'b': 3})

# %%
sum([Counter(l) for l in df.labels], Counter())
# Out:
# Counter({'MAN_MADE_EVENT.INDUSTRIAL_ACCIDENT': 120,
#          'MAN_MADE_EVENT.VEHICULAR_COLLISION': 643,
#          'MAN_MADE_EVENT.SHOOT_OUT': 341,
#          'MAN_MADE_EVENT.TERRORIST_ATTACK': 67,
#          'NATURAL_EVENT.EARTHQUAKE': 256,
#          'MAN_MADE_EVENT.SURGICAL_STRIKES': 106,
#          'MAN_MADE_EVENT.RIOTS': 15,
#          'MAN_MADE_EVENT.NORMAL_BOMBING': 153,
#          'MAN_MADE_EVENT.FIRE': 806,
#          'MAN_MADE_EVENT.TRANSPORT_HAZARDS': 323,
#          'MAN_MADE_EVENT.TRAIN_COLLISION': 109,
#          'NATURAL_EVENT.FLOODS': 158,
#          'NATURAL_EVENT.EPIDEMIC': 46,
#          'NATURAL_EVENT.VOLCANO': 88,
#          'NATURAL_EVENT.AVALANCHES': 33,
#          'NATURAL_EVENT.LIMNIC_ERRUPTIONS': 2,
#          'NATURAL_EVENT.TORNADO': 52,
#          'MAN_MADE_EVENT.AVIATION_HAZARD': 78,
#          'NATURAL_EVENT.COLD_WAVE': 23,
#          'NATURAL_EVENT.LAND_SLIDE': 64,
#          'NATURAL_EVENT.STORM': 104,
#          'NATURAL_EVENT.HURRICANE': 35,
#          'NATURAL_EVENT.CYCLONE': 87,
#          'NATURAL_EVENT.HAIL_STORMS': 23,
#          'NATURAL_EVENT.BLIZZARD': 10,
#          'MAN_MADE_EVENT.SUICIDE_ATTACK': 110,
#          'NATURAL_EVENT.FOREST_FIRE': 57,
#          'NATURAL_EVENT.HEAT_WAVE': 15,
#          'MAN_MADE_EVENT.ARMED_CONFLICTS': 11,
#          'NATURAL_EVENT.TSUNAMI': 11,
#          'MAN_MADE_EVENT.ACCIDENTS': 735,
#          'MAN_MADE_EVENT.CRIME': 98,
#          'MAN_MADE_EVENT.MISCELLANEOUS': 59,
#          'NATURAL_EVENT.ROCK_FALL': 3,
#          'NATURAL_EVENT.DROUGHT': 7,
#          'NATURAL_EVENT.HEAVY_RAINFALL': 1,
#          'NATURAL_EVENT.FAMINE': 1})

# %%
df.labels.apply(pd.Series).idxmax(axis=1)
# Out:
# 0      MAN_MADE_EVENT.INDUSTRIAL_ACCIDENT
# 1      MAN_MADE_EVENT.VEHICULAR_COLLISION
# 2                MAN_MADE_EVENT.SHOOT_OUT
# 3                NATURAL_EVENT.EARTHQUAKE
# 4                MAN_MADE_EVENT.SHOOT_OUT
#                       ...
# 823                 NATURAL_EVENT.DROUGHT
# 824        MAN_MADE_EVENT.TRAIN_COLLISION
# 825        MAN_MADE_EVENT.TRAIN_COLLISION
# 826               NATURAL_EVENT.HEAT_WAVE
# 827              NATURAL_EVENT.AVALANCHES
# Length: 828, dtype: object

# %%
(~df.labels.apply(pd.Series).isnull()).sum(axis=1).value_counts()
# Out:
# 1    672
# 2    118
# 3     30
# 4      8
# dtype: int64

# %%
X_train = df_train["tokens"]
y_train = df_train.labels.apply(pd.Series).idxmax(axis=1)

X_valid = df_valid["tokens"]
y_valid = df_valid.labels.apply(pd.Series).idxmax(axis=1)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline

# %%
clf = Pipeline([
    ("tfidf", TfidfVectorizer(tokenizer=lambda x: x, preprocessor=lambda x: x)),
    ("model", RandomForestClassifier(
        #min_samples_split=4, min_samples_leaf=4
    ))
])
clf.fit(X_train, y_train)
# Out:
# F:\ProgramData\Miniconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# Pipeline(memory=None,
#          steps=[('tfidf',
#                  TfidfVectorizer(analyzer='word', binary=False,
#                                  decode_error='strict',
#                                  dtype=<class 'numpy.float64'>,
#                                  encoding='utf-8', input='content',
#                                  lowercase=True, max_df=1.0, max_features=None,
#                                  min_df=1, ngram_range=(1, 1), norm='l2',
#                                  preprocessor=<function <lambda> at 0x00000152D56A6C80>,
#                                  smooth_idf=True, stop_words=None,
#                                  strip_accents=None,...
#                  RandomForestClassifier(bootstrap=True, class_weight=None,
#                                         criterion='gini', max_depth=None,
#                                         max_features='auto',
#                                         max_leaf_nodes=None,
#                                         min_impurity_decrease=0.0,
#                                         min_impurity_split=None,
#                                         min_samples_leaf=1, min_samples_split=2,
#                                         min_weight_fraction_leaf=0.0,
#                                         n_estimators=10, n_jobs=None,
#                                         oob_score=False, random_state=None,
#                                         verbose=0, warm_start=False))],
#          verbose=False)

# %%
y_pred = clf.predict(X_train)
print(classification_report(y_true=y_train, y_pred=y_pred))
# Out:
#                                     precision    recall  f1-score   support
#
#           MAN_MADE_EVENT.ACCIDENTS       0.96      0.99      0.98       132
#     MAN_MADE_EVENT.ARMED_CONFLICTS       1.00      1.00      1.00         1
#     MAN_MADE_EVENT.AVIATION_HAZARD       1.00      1.00      1.00        10
#               MAN_MADE_EVENT.CRIME       1.00      1.00      1.00        18
#                MAN_MADE_EVENT.FIRE       0.98      1.00      0.99       102
# MAN_MADE_EVENT.INDUSTRIAL_ACCIDENT       1.00      1.00      1.00        14
#       MAN_MADE_EVENT.MISCELLANEOUS       1.00      0.91      0.95        11
#      MAN_MADE_EVENT.NORMAL_BOMBING       1.00      1.00      1.00        19
#               MAN_MADE_EVENT.RIOTS       1.00      1.00      1.00         1
#           MAN_MADE_EVENT.SHOOT_OUT       1.00      0.98      0.99        50
#      MAN_MADE_EVENT.SUICIDE_ATTACK       1.00      1.00      1.00        10
#    MAN_MADE_EVENT.SURGICAL_STRIKES       1.00      1.00      1.00        12
#    MAN_MADE_EVENT.TERRORIST_ATTACK       1.00      1.00      1.00        10
#     MAN_MADE_EVENT.TRAIN_COLLISION       1.00      1.00      1.00        16
#   MAN_MADE_EVENT.TRANSPORT_HAZARDS       1.00      0.97      0.98        59
# MAN_MADE_EVENT.VEHICULAR_COLLISION       0.99      0.98      0.99       112
#           NATURAL_EVENT.AVALANCHES       1.00      1.00      1.00         6
#             NATURAL_EVENT.BLIZZARD       1.00      1.00      1.00         2
#            NATURAL_EVENT.COLD_WAVE       1.00      1.00      1.00         6
#              NATURAL_EVENT.CYCLONE       1.00      1.00      1.00        14
#           NATURAL_EVENT.EARTHQUAKE       1.00      1.00      1.00        43
#             NATURAL_EVENT.EPIDEMIC       1.00      1.00      1.00         4
#               NATURAL_EVENT.FLOODS       1.00      1.00      1.00        30
#          NATURAL_EVENT.FOREST_FIRE       1.00      0.83      0.91         6
#          NATURAL_EVENT.HAIL_STORMS       1.00      1.00      1.00         5
#            NATURAL_EVENT.HEAT_WAVE       1.00      1.00      1.00         3
#            NATURAL_EVENT.HURRICANE       1.00      1.00      1.00         4
#           NATURAL_EVENT.LAND_SLIDE       1.00      1.00      1.00        10
#                NATURAL_EVENT.STORM       1.00      1.00      1.00        10
#              NATURAL_EVENT.TORNADO       1.00      1.00      1.00         9
#              NATURAL_EVENT.TSUNAMI       1.00      1.00      1.00         1
#              NATURAL_EVENT.VOLCANO       1.00      1.00      1.00        15
#
#                           accuracy                           0.99       745
#                          macro avg       1.00      0.99      0.99       745
#                       weighted avg       0.99      0.99      0.99       745

# %%
y_pred = clf.predict(X_valid)
print(classification_report(y_true=y_valid, y_pred=y_pred))
# Out:
#                                     precision    recall  f1-score   support
#
#           MAN_MADE_EVENT.ACCIDENTS       0.26      0.62      0.36        13
#     MAN_MADE_EVENT.AVIATION_HAZARD       0.00      0.00      0.00         3
#               MAN_MADE_EVENT.CRIME       0.00      0.00      0.00         2
#                MAN_MADE_EVENT.FIRE       0.71      1.00      0.83        12
# MAN_MADE_EVENT.INDUSTRIAL_ACCIDENT       0.50      0.50      0.50         2
#       MAN_MADE_EVENT.MISCELLANEOUS       1.00      0.50      0.67         2
#      MAN_MADE_EVENT.NORMAL_BOMBING       0.00      0.00      0.00         3
#               MAN_MADE_EVENT.RIOTS       0.00      0.00      0.00         1
#           MAN_MADE_EVENT.SHOOT_OUT       0.67      1.00      0.80         2
#      MAN_MADE_EVENT.SUICIDE_ATTACK       0.00      0.00      0.00         1
#    MAN_MADE_EVENT.SURGICAL_STRIKES       0.00      0.00      0.00         2
#     MAN_MADE_EVENT.TRAIN_COLLISION       0.75      1.00      0.86         3
#   MAN_MADE_EVENT.TRANSPORT_HAZARDS       0.00      0.00      0.00         6
# MAN_MADE_EVENT.VEHICULAR_COLLISION       0.36      0.33      0.35        12
#           NATURAL_EVENT.AVALANCHES       0.00      0.00      0.00         1
#            NATURAL_EVENT.COLD_WAVE       0.00      0.00      0.00         1
#              NATURAL_EVENT.CYCLONE       0.00      0.00      0.00         1
#              NATURAL_EVENT.DROUGHT       0.00      0.00      0.00         1
#           NATURAL_EVENT.EARTHQUAKE       0.60      0.75      0.67         4
#               NATURAL_EVENT.FLOODS       0.20      1.00      0.33         1
#          NATURAL_EVENT.FOREST_FIRE       0.00      0.00      0.00         2
#            NATURAL_EVENT.HURRICANE       0.00      0.00      0.00         2
#           NATURAL_EVENT.LAND_SLIDE       0.00      0.00      0.00         2
#                NATURAL_EVENT.STORM       0.00      0.00      0.00         2
#              NATURAL_EVENT.TORNADO       0.00      0.00      0.00         1
#              NATURAL_EVENT.VOLCANO       0.00      0.00      0.00         1
#
#                           accuracy                           0.42        83
#                          macro avg       0.19      0.26      0.21        83
#                       weighted avg       0.31      0.42      0.34        83
# F:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
y_pred = clf.predict(X_train)
print(classification_report(y_true=transform_label(y_train), y_pred=transform_label(y_pred)))
# Out:
#                 precision    recall  f1-score   support
#
# MAN_MADE_EVENT       1.00      1.00      1.00       577
#  NATURAL_EVENT       1.00      0.99      1.00       168
#
#       accuracy                           1.00       745
#      macro avg       1.00      1.00      1.00       745
#   weighted avg       1.00      1.00      1.00       745

# %%
y_pred = clf.predict(X_valid)
print(classification_report(y_true=transform_label(y_valid), y_pred=transform_label(y_pred)))
# Out:
#                 precision    recall  f1-score   support
#
# MAN_MADE_EVENT       0.90      1.00      0.95        64
#  NATURAL_EVENT       1.00      0.63      0.77        19
#
#       accuracy                           0.92        83
#      macro avg       0.95      0.82      0.86        83
#   weighted avg       0.92      0.92      0.91        83

# %%
clf_map = {
    c: c.split(".")[0]
    for c in clf.classes_
}

# %%
clf.predict_proba(X_valid)
clf.classes_
# Out:
# array(['MAN_MADE_EVENT.ACCIDENTS', 'MAN_MADE_EVENT.ARMED_CONFLICTS',
#        'MAN_MADE_EVENT.AVIATION_HAZARD', 'MAN_MADE_EVENT.CRIME',
#        'MAN_MADE_EVENT.FIRE', 'MAN_MADE_EVENT.INDUSTRIAL_ACCIDENT',
#        'MAN_MADE_EVENT.MISCELLANEOUS', 'MAN_MADE_EVENT.NORMAL_BOMBING',
#        'MAN_MADE_EVENT.RIOTS', 'MAN_MADE_EVENT.SHOOT_OUT',
#        'MAN_MADE_EVENT.SUICIDE_ATTACK', 'MAN_MADE_EVENT.SURGICAL_STRIKES',
#        'MAN_MADE_EVENT.TERRORIST_ATTACK',
#        'MAN_MADE_EVENT.TRAIN_COLLISION',
#        'MAN_MADE_EVENT.TRANSPORT_HAZARDS',
#        'MAN_MADE_EVENT.VEHICULAR_COLLISION', 'NATURAL_EVENT.AVALANCHES',
#        'NATURAL_EVENT.BLIZZARD', 'NATURAL_EVENT.COLD_WAVE',
#        'NATURAL_EVENT.CYCLONE', 'NATURAL_EVENT.EARTHQUAKE',
#        'NATURAL_EVENT.EPIDEMIC', 'NATURAL_EVENT.FLOODS',
#        'NATURAL_EVENT.FOREST_FIRE', 'NATURAL_EVENT.HAIL_STORMS',
#        'NATURAL_EVENT.HEAT_WAVE', 'NATURAL_EVENT.HURRICANE',
#        'NATURAL_EVENT.LAND_SLIDE', 'NATURAL_EVENT.STORM',
#        'NATURAL_EVENT.TORNADO', 'NATURAL_EVENT.TSUNAMI',
#        'NATURAL_EVENT.VOLCANO'], dtype=object)

# %%
y_pred = clf.predict_proba(X_train)
print(classification_report(y_true=transform_label(y_train), y_pred=transform_probs(y_pred, clf)))
# Out:
#                 precision    recall  f1-score   support
#
# MAN_MADE_EVENT       0.99      1.00      1.00       577
#  NATURAL_EVENT       1.00      0.98      0.99       168
#
#       accuracy                           0.99       745
#      macro avg       1.00      0.99      0.99       745
#   weighted avg       0.99      0.99      0.99       745

# %%
y_pred = clf.predict_proba(X_valid)
print(classification_report(y_true=transform_label(y_valid), y_pred=transform_probs(y_pred, clf)))
# Out:
#                 precision    recall  f1-score   support
#
# MAN_MADE_EVENT       0.93      1.00      0.96        64
#  NATURAL_EVENT       1.00      0.74      0.85        19
#
#       accuracy                           0.94        83
#      macro avg       0.96      0.87      0.91        83
#   weighted avg       0.94      0.94      0.94        83

# %%
import sklearn_crfsuite

# %%
def word2features(sent, i):
    word = sent[i][0]
    #postag = sent[i][1]

    features = {
        'bias': 1.0,
        'word.lower()': word.lower(),
        'word[-3:]': word[-3:],
        'word[-2:]': word[-2:],
        'word.isupper()': word.isupper(),
        'word.istitle()': word.istitle(),
        'word.isdigit()': word.isdigit(),
        #'postag': postag,
        #'postag[:2]': postag[:2],
    }
    if i > 0:
        word1 = sent[i-1][0]
        postag1 = sent[i-1][1]
        features.update({
            '-1:word.lower()': word1.lower(),
            '-1:word.istitle()': word1.istitle(),
            '-1:word.isupper()': word1.isupper(),
            #'-1:postag': postag1,
            #'-1:postag[:2]': postag1[:2],
        })
    else:
        features['BOS'] = True

    if i < len(sent)-1:
        word1 = sent[i+1][0]
        #postag1 = sent[i+1][1]
        features.update({
            '+1:word.lower()': word1.lower(),
            '+1:word.istitle()': word1.istitle(),
            '+1:word.isupper()': word1.isupper(),
            #'+1:postag': postag1,
            #'+1:postag[:2]': postag1[:2],
        })
    else:
        features['EOS'] = True

    return features


def sent2features(sent):
    return [word2features(sent, i) for i in range(len(sent))]

def sent2labels(sent):
    return [label for token, label in sent]

def sent2tokens(sent):
    return [token for token, label in sent]


def df_to_Xy(df):
    sentences = [list(zip(*row[["tokens", "tags"]])) for i, row in df.iterrows()]
    X = [sent2features(s) for s in sentences]
    y = [sent2labels(s) for s in sentences]
    return X, y

# %%
df_train.loc[0, ["tokens", "tags"]]
# Out:
# tokens    [1, dead,, 18, hurt, in, explosion, at, natura...
# tags      [B-CASUALTIES-ARG, I-CASUALTIES-ARG, I-CASUALT...
# Name: 0, dtype: object

# %%
list(zip(*df_train.loc[0, ["tokens", "tags"]]))
# Out:
# [('1', 'B-CASUALTIES-ARG'),
#  ('dead,', 'I-CASUALTIES-ARG'),
#  ('18', 'I-CASUALTIES-ARG'),
#  ('hurt', 'I-CASUALTIES-ARG'),
#  ('in', 'O'),
#  ('explosion', 'B-MAN_MADE_EVENT.INDUSTRIAL_ACCIDENT'),
#  ('at', 'O'),
#  ('natural', 'B-PLACE-ARG'),
#  ('gas', 'I-PLACE-ARG'),
#  ('plant', 'I-PLACE-ARG'),
#  ('An', 'O'),
#  ('explosion', 'B-MAN_MADE_EVENT.INDUSTRIAL_ACCIDENT'),
#  ('on', 'O'),
#  ('Tuesday', 'B-TIME-ARG'),
#  ('at', 'O'),
#  ('a', 'O'),
#  ('natural', 'B-PLACE-ARG'),
#  ('gas', 'I-PLACE-ARG'),
#  ('facility', 'I-PLACE-ARG'),
#  ('near', 'I-PLACE-ARG'),
#  ('Austria’s', 'I-PLACE-ARG'),
#  ('border', 'I-PLACE-ARG'),
#  ('with', 'I-PLACE-ARG'),
#  ('Slovakia', 'I-PLACE-ARG'),
#  ('left', 'O'),
#  ('one', 'B-CASUALTIES-ARG'),
#  ('person', 'I-CASUALTIES-ARG'),
#  ('dead,', 'I-CASUALTIES-ARG'),
#  ('authorities', 'O'),
#  ('said.', 'O'),
#  ('A', 'O'),
#  ('further', 'O'),
#  ('18', 'B-CASUALTIES-ARG'),
#  ('people', 'I-CASUALTIES-ARG'),
#  ('were', 'I-CASUALTIES-ARG'),
#  ('injured', 'I-CASUALTIES-ARG'),
#  ('in', 'B-TIME-ARG'),
#  ('the', 'I-TIME-ARG'),
#  ('morning', 'I-TIME-ARG'),
#  ('blast', 'B-MAN_MADE_EVENT.INDUSTRIAL_ACCIDENT'),
#  ('at', 'O'),
#  ('the', 'O'),
#  ('plant', 'B-PLACE-ARG'),
#  ('in', 'I-PLACE-ARG'),
#  ('Baumgarten', 'I-PLACE-ARG'),
#  ('an', 'I-PLACE-ARG'),
#  ('der', 'I-PLACE-ARG'),
#  ('March,', 'I-PLACE-ARG'),
#  ('east', 'I-PLACE-ARG'),
#  ('of', 'I-PLACE-ARG'),
#  ('Vienna,', 'I-PLACE-ARG'),
#  ('regional', 'O'),
#  ('Red', 'O'),
#  ('Cross', 'O'),
#  ('official', 'O'),
#  ('Sonja', 'O'),
#  ('Kellner', 'O'),
#  ('said.', 'O'),
#  ('Two', 'O'),
#  ('medical', 'O'),
#  ('helicopters', 'O'),
#  ('were', 'O'),
#  ('sent', 'O'),
#  ('to', 'O'),
#  ('the', 'O'),
#  ('scene,', 'O'),
#  ('the', 'O'),
#  ('Austria', 'O'),
#  ('Press', 'O'),
#  ('Agency', 'O'),
#  ('reported.', 'O'),
#  ('The', 'O'),
#  ('explosion', 'B-MAN_MADE_EVENT.INDUSTRIAL_ACCIDENT'),
#  ('set', 'O'),
#  ('off', 'O'),
#  ('a', 'O'),
#  ('fire,', 'B-AFTER_EFFECTS-ARG'),
#  ('which', 'O'),
#  ('operator', 'O'),
#  ('Gas', 'O'),
#  ('Connect', 'O'),
#  ('said', 'O'),
#  ('was', 'O'),
#  ('contained', 'O'),
#  ('by', 'O'),
#  ('midmorning.', 'O'),
#  ('The', 'O'),
#  ('facility', 'O'),
#  ('was', 'O'),
#  ('shut', 'O'),
#  ('down,', 'O'),
#  ('Gas', 'O'),
#  ('Connect', 'O'),
#  ('spokesman', 'O'),
#  ('Armin', 'O'),
#  ('Teichert', 'O'),
#  ('said.', 'O'),
#  ('Police', 'O'),
#  ('wrote', 'O'),
#  ('on', 'O'),
#  ('Twitter', 'O'),
#  ('that', 'O'),
#  ('the', 'O'),
#  ('situation', 'O'),
#  ('“is', 'O'),
#  ('under', 'O'),
#  ('control.”', 'O'),
#  ('There', 'O'),
#  ('was', 'O'),
#  ('no', 'O'),
#  ('immediate', 'O'),
#  ('word', 'O'),
#  ('on', 'O'),
#  ('what', 'O'),
#  ('caused', 'O'),
#  ('the', 'O'),
#  ('blast', 'B-MAN_MADE_EVENT.INDUSTRIAL_ACCIDENT'),
#  ('at', 'O'),
#  ('the', 'O'),
#  ('plant,', 'B-PLACE-ARG'),
#  ('where', 'O'),
#  ('pipelines', 'O'),
#  ('connect', 'O'),
#  ('and', 'O'),
#  ('gas', 'O'),
#  ('from', 'O'),
#  ('Russia,', 'O'),
#  ('Norway', 'O'),
#  ('and', 'O'),
#  ('other', 'O'),
#  ('countries', 'O'),
#  ('is', 'O'),
#  ('compressed.', 'O')]

# %%
for i, row in df_train.iterrows():
    print(row)
    sent = list(zip(*row[["tokens", "tags"]]))
    print(sent)
    break
# Out:
# docid                                               file290
# tokens    [10, die, in, Egypt, church, attack., Ten, per...
# tags      [B-CASUALTIES-ARG, I-CASUALTIES-ARG, O, B-PLAC...
# labels               {'MAN_MADE_EVENT.TERRORIST_ATTACK': 7}
# Name: 212, dtype: object
# [('10', 'B-CASUALTIES-ARG'), ('die', 'I-CASUALTIES-ARG'), ('in', 'O'), ('Egypt', 'B-PLACE-ARG'), ('church', 'I-PLACE-ARG'), ('attack.', 'B-MAN_MADE_EVENT.TERRORIST_ATTACK'), ('Ten', 'B-CASUALTIES-ARG'), ('persons', 'I-CASUALTIES-ARG'), ('were', 'I-CASUALTIES-ARG'), ('killed', 'I-CASUALTIES-ARG'), ('and', 'I-CASUALTIES-ARG'), ('eight', 'I-CASUALTIES-ARG'), ('others', 'I-CASUALTIES-ARG'), ('injured', 'I-CASUALTIES-ARG'), ('in', 'O'), ('a', 'O'), ('terrorist', 'B-MAN_MADE_EVENT.TERRORIST_ATTACK'), ('attack', 'I-MAN_MADE_EVENT.TERRORIST_ATTACK'), ('on', 'O'), ('a', 'O'), ('church', 'B-PLACE-ARG'), ('in', 'I-PLACE-ARG'), ('Egypt’s', 'I-PLACE-ARG'), ('capital', 'I-PLACE-ARG'), ('today,', 'B-TIME-ARG'), ('the', 'O'), ('government', 'O'), ('said.', 'O'), ('A', 'O'), ('health', 'O'), ('ministry', 'O'), ('spokesman', 'O'), ('said', 'O'), ('the', 'O'), ('attack', 'B-MAN_MADE_EVENT.TERRORIST_ATTACK'), ('took', 'O'), ('place', 'O'), ('when', 'O'), ('gunmen', 'B-PARTICIPANT-ARG'), ('on', 'O'), ('a', 'O'), ('motorbike', 'O'), ('opened', 'B-MAN_MADE_EVENT.TERRORIST_ATTACK'), ('fire', 'I-MAN_MADE_EVENT.TERRORIST_ATTACK'), ('outside', 'O'), ('Mar', 'B-PLACE-ARG'), ('Mina', 'I-PLACE-ARG'), ('church', 'I-PLACE-ARG'), ('in', 'I-PLACE-ARG'), ('Helwan', 'I-PLACE-ARG'), ('area.', 'I-PLACE-ARG'), ('At', 'B-CASUALTIES-ARG'), ('least', 'I-CASUALTIES-ARG'), ('10', 'I-CASUALTIES-ARG'), ('persons,', 'I-CASUALTIES-ARG'), ('including', 'I-CASUALTIES-ARG'), ('eight', 'I-CASUALTIES-ARG'), ('Coptic', 'I-CASUALTIES-ARG'), ('Christians,', 'I-CASUALTIES-ARG'), ('were', 'I-CASUALTIES-ARG'), ('killed', 'I-CASUALTIES-ARG'), ('in', 'O'), ('the', 'O'), ('shootout', 'B-MAN_MADE_EVENT.TERRORIST_ATTACK'), ('outside', 'O'), ('the', 'O'), ('south', 'B-PLACE-ARG'), ('Cairo', 'I-PLACE-ARG'), ('church,', 'I-PLACE-ARG'), ('he', 'O'), ('said,', 'O'), ('adding,', 'O'), ('one', 'O'), ('gunman', 'B-CASUALTIES-ARG'), ('was', 'I-CASUALTIES-ARG'), ('shot', 'I-CASUALTIES-ARG'), ('dead', 'I-CASUALTIES-ARG'), ('as', 'O'), ('was', 'O'), ('a', 'O'), ('security', 'O'), ('officer.', 'O'), ('The', 'O'), ('ministry', 'O'), ('said', 'O'), ('two', 'O'), ('of', 'O'), ('the', 'O'), ('injured', 'O'), ('are', 'O'), ('women,', 'O'), ('adding', 'O'), ('it', 'O'), ('employed', 'O'), ('10', 'O'), ('ambulances', 'O'), ('to', 'O'), ('transfer', 'O'), ('the', 'O'), ('injured', 'O'), ('to', 'O'), ('hospitals.', 'O'), ('State-run', 'O'), ('MENA', 'O'), ('news', 'O'), ('agency', 'O'), ('reported', 'O'), ('that', 'O'), ('the', 'O'), ('other', 'O'), ('gunman', 'O'), ('fled', 'O'), ('the', 'O'), ('scene.', 'O'), ('There', 'O'), ('was', 'O'), ('no', 'O'), ('immediate', 'O'), ('claim', 'O'), ('of', 'O'), ('responsibility', 'O'), ('for', 'O'), ('the', 'O'), ('attack.', 'B-MAN_MADE_EVENT.TERRORIST_ATTACK'), ('The', 'O'), ('attack', 'B-MAN_MADE_EVENT.TERRORIST_ATTACK'), ('comes', 'O'), ('days', 'O'), ('before', 'O'), ('the', 'O'), ('Coptic', 'O'), ('celebration', 'O'), ('of', 'O'), ('New', 'O'), ('Year', 'O'), ('and', 'O'), ('orthodox', 'O'), ('Christmas', 'O'), ('Day', 'O'), ('on', 'O'), ('January', 'O'), ('7.', 'O'), ('—', 'O'), ('PTI', 'O')]

# %%
sent2features(list(zip(*df_train.loc[0, ["tokens", "tags"]])))[0]
# Out:
# {'bias': 1.0,
#  'word.lower()': '1',
#  'word[-3:]': '1',
#  'word[-2:]': '1',
#  'word.isupper()': False,
#  'word.istitle()': False,
#  'word.isdigit()': True,
#  'BOS': True,
#  '+1:word.lower()': 'dead,',
#  '+1:word.istitle()': False,
#  '+1:word.isupper()': False}

# %%
# %%time
X_train, y_train = df_to_Xy(df_train)
X_valid, y_valid = df_to_Xy(df_valid)
# Out:
# Wall time: 1.18 s

# %%
# %%time
crf = sklearn_crfsuite.CRF(
    algorithm='ap',
    max_iterations=100,
    all_possible_transitions=False
)
crf.fit(X_train, y_train)
# Out:
# Wall time: 3min 51s
# CRF(algorithm='ap', all_possible_states=None, all_possible_transitions=False,
#     averaging=None, c=None, c1=None, c2=None, calibration_candidates=None,
#     calibration_eta=None, calibration_max_trials=None, calibration_rate=None,
#     calibration_samples=None, delta=None, epsilon=None, error_sensitive=None,
#     gamma=None, keep_tempfiles=None, linesearch=None, max_iterations=100,
#     max_linesearch=None, min_freq=None, model_filename=None, num_memories=None,
#     pa_type=None, period=None, trainer_cls=None, variance=None, verbose=False)

# %%
y_pred = crf.predict(X_valid)

# %%
y_pred
# Out:
# [['O',
#   'O',
#   'O',
#   'B-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'O',
#   'B-PLACE-ARG',
#   'B-NATURAL_EVENT.LAND_SLIDE',
#   'B-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'O',
#   'O',
#   'B-NATURAL_EVENT.LAND_SLIDE',
#   'O',
#   'B-PLACE-ARG',
#   'I-PLACE-ARG',
#   'I-PLACE-ARG',
#   'I-PLACE-ARG',
#   'O',
#   'B-TIME-ARG',
#   'I-TIME-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-NATURAL_EVENT.LAND_SLIDE',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.MISCELLANEOUS',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.FIRE',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'B-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'O',
#   'B-MAN_MADE_EVENT.ACCIDENTS',
#   'I-MAN_MADE_EVENT.ACCIDENTS',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.ACCIDENTS',
#   'B-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'O',
#   'B-PLACE-ARG',
#   'O',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.VEHICULAR_COLLISION',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-TIME-ARG',
#   'O',
#   'B-MAN_MADE_EVENT.VEHICULAR_COLLISION',
#   'O',
#   'O',
#   'O',
#   'B-PLACE-ARG',
#   'I-PLACE-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-REASON-ARG',
#   'I-REASON-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.ACCIDENTS',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.ACCIDENTS',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'B-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'O',
#   'B-MAN_MADE_EVENT.ACCIDENTS',
#   'O',
#   'B-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.ACCIDENTS',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-TIME-ARG',
#   'I-TIME-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.VEHICULAR_COLLISION',
#   'O',
#   'B-TIME-ARG',
#   'I-TIME-ARG',
#   'I-TIME-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.VEHICULAR_COLLISION',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'B-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'O',
#   'B-PLACE-ARG',
#   'I-PLACE-ARG',
#   'I-PLACE-ARG',
#   'B-MAN_MADE_EVENT.FIRE',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.FIRE',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'O',
#   'B-PLACE-ARG',
#   'I-PLACE-ARG',
#   'O',
#   'B-MAN_MADE_EVENT.FIRE',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.FIRE',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.FIRE',
#   'I-MAN_MADE_EVENT.FIRE',
#   'O',
#   'B-MAN_MADE_EVENT.FIRE',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-TIME-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.FIRE',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.FIRE',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-TIME-ARG',
#   'I-TIME-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-MAN_MADE_EVENT.FIRE',
#   'O',
#   'B-PLACE-ARG',
#   'I-PLACE-ARG',
#   'O',
#   'B-PLACE-ARG',
#   'I-PLACE-ARG',
#   'I-PLACE-ARG',
#   'I-PLACE-ARG',
#   'I-PLACE-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PLACE-ARG',
#   'I-PLACE-ARG',
#   'I-PLACE-ARG',
#   'I-PLACE-ARG',
#   'I-PLACE-ARG',
#   'I-PLACE-ARG',
#   'I-PLACE-ARG',
#   'I-PLACE-ARG',
#   'I-PLACE-ARG',
#   'I-PLACE-ARG',
#   'O',
#   'B-MAN_MADE_EVENT.FIRE',
#   'O',
#   'B-TIME-ARG',
#   'I-TIME-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'O',
#   'B-MAN_MADE_EVENT.FIRE',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.ACCIDENTS',
#   'I-MAN_MADE_EVENT.ACCIDENTS',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PLACE-ARG',
#   'I-PLACE-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.FIRE',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PLACE-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'B-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'O',
#   'B-MAN_MADE_EVENT.ACCIDENTS',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-TIME-ARG',
#   'I-TIME-ARG',
#   'O',
#   'B-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'O',
#   'O',
#   'O',
#   'B-TIME-ARG',
#   'I-TIME-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.ACCIDENTS',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-TIME-ARG',
#   'I-TIME-ARG',
#   'O',
#   'O',
#   'O',
#   'B-TIME-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.FIRE',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-INTENSITY-ARG',
#   'B-NATURAL_EVENT.EARTHQUAKE',
#   'O',
#   'B-PLACE-ARG',
#   'I-PLACE-ARG',
#   'I-PLACE-ARG',
#   'B-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'O',
#   'O',
#   'B-INTENSITY-ARG',
#   'B-NATURAL_EVENT.EARTHQUAKE',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PLACE-ARG',
#   'I-PLACE-ARG',
#   'O',
#   'B-TIME-ARG',
#   'I-TIME-ARG',
#   'B-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MAGNITUDE-ARG',
#   'I-MAGNITUDE-ARG',
#   'B-NATURAL_EVENT.EARTHQUAKE',
#   'O',
#   'O',
#   'B-TIME-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-NATURAL_EVENT.EARTHQUAKE',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PLACE-ARG',
#   'I-PLACE-ARG',
#   'I-PLACE-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-NATURAL_EVENT.EARTHQUAKE',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-NATURAL_EVENT.EARTHQUAKE',
#   'O',
#   'O',
#   'O'],
#  ['B-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PLACE-ARG',
#   'I-PLACE-ARG',
#   'I-PLACE-ARG',
#   'I-PLACE-ARG',
#   'O',
#   'O',
#   'B-TIME-ARG',
#   'I-TIME-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PLACE-ARG',
#   'I-PLACE-ARG',
#   'I-PLACE-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.CRIME',
#   'I-MAN_MADE_EVENT.CRIME',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.SHOOT_OUT',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PLACE-ARG',
#   'I-PLACE-ARG',
#   'I-PLACE-ARG',
#   'I-PLACE-ARG',
#   'O',
#   'B-TIME-ARG',
#   'I-TIME-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.SHOOT_OUT',
#   'O',
#   'O',
#   'B-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-TIME-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.SHOOT_OUT',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.SHOOT_OUT',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'B-NATURAL_EVENT.CYCLONE',
#   'I-NATURAL_EVENT.CYCLONE',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-NATURAL_EVENT.CYCLONE',
#   'O',
#   'O',
#   'B-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-NATURAL_EVENT.CYCLONE',
#   'I-NATURAL_EVENT.CYCLONE',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'O',
#   'B-NATURAL_EVENT.STORM',
#   'O',
#   'B-PLACE-ARG',
#   'B-TIME-ARG',
#   'I-TIME-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-NATURAL_EVENT.STORM',
#   'B-NATURAL_EVENT.FLOODS',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-NATURAL_EVENT.FLOODS',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'O',
#   'O',
#   'B-NATURAL_EVENT.FLOODS',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PLACE-ARG',
#   'I-PLACE-ARG',
#   'I-PLACE-ARG',
#   'I-PLACE-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.ACCIDENTS',
#   'I-MAN_MADE_EVENT.ACCIDENTS',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PLACE-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'B-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'O',
#   'B-MAN_MADE_EVENT.TRANSPORT_HAZARDS',
#   'I-MAN_MADE_EVENT.TRANSPORT_HAZARDS',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.TRANSPORT_HAZARDS',
#   'I-MAN_MADE_EVENT.TRANSPORT_HAZARDS',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-TIME-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-REASON-ARG',
#   'I-REASON-ARG',
#   'I-REASON-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-REASON-ARG',
#   'I-REASON-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-TIME-ARG',
#   'I-TIME-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PLACE-ARG',
#   'I-PLACE-ARG',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.VEHICULAR_COLLISION',
#   'O',
#   'O'],
#  ['O',
#   'B-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.VEHICULAR_COLLISION',
#   'O',
#   'O',
#   'O',
#   'B-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'O',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.VEHICULAR_COLLISION',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-TIME-ARG',
#   'I-TIME-ARG',
#   'I-TIME-ARG',
#   'I-TIME-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.ACCIDENTS',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-INTENSITY-ARG',
#   'B-NATURAL_EVENT.EARTHQUAKE',
#   'O',
#   'B-PLACE-ARG',
#   'O',
#   'B-MAGNITUDE-ARG',
#   'I-MAGNITUDE-ARG',
#   'B-NATURAL_EVENT.EARTHQUAKE',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-DEPTH-ARG',
#   'I-DEPTH-ARG',
#   'I-DEPTH-ARG',
#   'I-DEPTH-ARG',
#   'O',
#   'O',
#   'O',
#   'B-TIME-ARG',
#   'I-TIME-ARG',
#   'I-TIME-ARG',
#   'O',
#   'O',
#   'O',
#   'B-NATURAL_EVENT.EARTHQUAKE',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MAGNITUDE-ARG',
#   'I-MAGNITUDE-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-NATURAL_EVENT.EARTHQUAKE',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-NATURAL_EVENT.EARTHQUAKE',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MAGNITUDE-ARG',
#   'I-MAGNITUDE-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'O',
#   'O',
#   'B-PLACE-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-NATURAL_EVENT.EARTHQUAKE',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-NATURAL_EVENT.EARTHQUAKE',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-NATURAL_EVENT.EARTHQUAKE',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-NATURAL_EVENT.COLD_WAVE',
#   'I-NATURAL_EVENT.COLD_WAVE',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.CRIME',
#   'B-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PLACE-ARG',
#   'O',
#   'O',
#   'O',
#   'B-PLACE-ARG',
#   'I-PLACE-ARG',
#   'I-PLACE-ARG',
#   'I-PLACE-ARG',
#   'I-PLACE-ARG',
#   'B-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.TERRORIST_ATTACK',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.NORMAL_BOMBING',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PLACE-ARG',
#   'I-PLACE-ARG',
#   'I-PLACE-ARG',
#   'I-PLACE-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-MAN_MADE_EVENT.TRAIN_COLLISION',
#   'I-MAN_MADE_EVENT.TRAIN_COLLISION',
#   'B-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.VEHICULAR_COLLISION',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-TIME-ARG',
#   'B-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.TRAIN_COLLISION',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PLACE-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.ACCIDENTS',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.FIRE',
#   'I-MAN_MADE_EVENT.FIRE',
#   'B-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.FIRE',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PLACE-ARG',
#   'I-PLACE-ARG',
#   'O',
#   'B-TIME-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.FIRE',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-REASON-ARG',
#   'I-REASON-ARG',
#   'I-REASON-ARG',
#   'O',
#   'B-MAN_MADE_EVENT.FIRE',
#   'O',
#   'O',
#   'O',
#   'B-TIME-ARG',
#   'O',
#   'B-TIME-ARG',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.FIRE',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-NATURAL_EVENT.FOREST_FIRE',
#   'I-NATURAL_EVENT.FOREST_FIRE',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.FIRE',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.FIRE',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.FIRE',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.ACCIDENTS',
#   'I-MAN_MADE_EVENT.ACCIDENTS',
#   'B-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.ACCIDENTS',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-TIME-ARG',
#   'I-TIME-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.ACCIDENTS',
#   'I-MAN_MADE_EVENT.ACCIDENTS',
#   'O',
#   'B-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.FIRE',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'B-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'O',
#   'B-MAN_MADE_EVENT.VEHICULAR_COLLISION',
#   'O',
#   'B-PLACE-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.VEHICULAR_COLLISION',
#   'B-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'O',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.VEHICULAR_COLLISION',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-TIME-ARG',
#   'I-TIME-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.VEHICULAR_COLLISION',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PLACE-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.TRAIN_COLLISION',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'B-MAN_MADE_EVENT.ACCIDENTS',
#   'I-MAN_MADE_EVENT.ACCIDENTS',
#   'O',
#   'O',
#   'B-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.ACCIDENTS',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-TIME-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.VEHICULAR_COLLISION',
#   'O',
#   'B-TIME-ARG',
#   'I-TIME-ARG',
#   'I-TIME-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.ACCIDENTS',
#   'I-MAN_MADE_EVENT.ACCIDENTS',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.ACCIDENTS',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PLACE-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PLACE-ARG',
#   'B-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PLACE-ARG',
#   'I-PLACE-ARG',
#   'I-PLACE-ARG',
#   'I-PLACE-ARG',
#   'O',
#   'B-TIME-ARG',
#   'B-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PLACE-ARG',
#   'O',
#   'B-MAN_MADE_EVENT.VEHICULAR_COLLISION',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PLACE-ARG',
#   'O',
#   'O',
#   'O',
#   'B-PLACE-ARG',
#   'I-PLACE-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-TIME-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PLACE-ARG',
#   'O',
#   'B-TIME-ARG',
#   'I-TIME-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-TIME-ARG',
#   'I-TIME-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.VEHICULAR_COLLISION',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.VEHICULAR_COLLISION',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.ACCIDENTS',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-REASON-ARG',
#   'I-REASON-ARG',
#   'I-REASON-ARG',
#   'I-REASON-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.VEHICULAR_COLLISION',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.ACCIDENTS',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PLACE-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'B-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PLACE-ARG',
#   'I-PLACE-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.ACCIDENTS',
#   'I-MAN_MADE_EVENT.ACCIDENTS',
#   'O',
#   'O',
#   'O',
#   'B-PLACE-ARG',
#   'I-PLACE-ARG',
#   'I-PLACE-ARG',
#   'I-PLACE-ARG',
#   'I-PLACE-ARG',
#   'I-PLACE-ARG',
#   'I-PLACE-ARG',
#   'O',
#   'O',
#   'B-PLACE-ARG',
#   'I-PLACE-ARG',
#   'I-PLACE-ARG',
#   'B-TIME-ARG',
#   'I-TIME-ARG',
#   'I-TIME-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-TIME-ARG',
#   'I-TIME-ARG',
#   'I-TIME-ARG',
#   'I-TIME-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'B-MAN_MADE_EVENT.FIRE',
#   'O',
#   'O',
#   'O',
#   'B-PLACE-ARG',
#   'I-PLACE-ARG',
#   'O',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.FIRE',
#   'O',
#   'O',
#   'O',
#   'B-PLACE-ARG',
#   'I-PLACE-ARG',
#   'I-PLACE-ARG',
#   'I-PLACE-ARG',
#   'I-PLACE-ARG',
#   'O',
#   'B-TIME-ARG',
#   'I-TIME-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.FIRE',
#   'I-MAN_MADE_EVENT.FIRE',
#   'O',
#   'O',
#   'O',
#   'B-TIME-ARG',
#   'I-TIME-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.ACCIDENTS',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.FIRE',
#   'I-MAN_MADE_EVENT.FIRE',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PLACE-ARG',
#   'I-PLACE-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.FIRE',
#   'I-MAN_MADE_EVENT.FIRE',
#   'O'],
#  ['B-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'O',
#   'B-MAN_MADE_EVENT.ACCIDENTS',
#   'I-MAN_MADE_EVENT.ACCIDENTS',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.ACCIDENTS',
#   'I-MAN_MADE_EVENT.ACCIDENTS',
#   'O',
#   'O',
#   'B-TIME-ARG',
#   'I-TIME-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PLACE-ARG',
#   'I-PLACE-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'O',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.VEHICULAR_COLLISION',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.ACCIDENTS',
#   'B-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.ACCIDENTS',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-CASUALTIES-ARG',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.ACCIDENTS',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-CASUALTIES-ARG',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.ACCIDENTS',
#   'O',
#   'B-PLACE-ARG',
#   'I-PLACE-ARG',
#   'I-PLACE-ARG',
#   'O',
#   'B-TIME-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PLACE-ARG',
#   'I-PLACE-ARG',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.ACCIDENTS',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.TRANSPORT_HAZARDS',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PLACE-ARG',
#   'I-PLACE-ARG',
#   'I-PLACE-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.ACCIDENTS',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.ACCIDENTS',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
# ...
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PLACE-ARG',
#   'I-PLACE-ARG',
#   'I-PLACE-ARG',
#   'I-PLACE-ARG',
#   'I-PLACE-ARG',
#   'I-PLACE-ARG',
#   'I-PLACE-ARG',
#   'I-PLACE-ARG',
#   'O',
#   'B-TIME-ARG',
#   'I-TIME-ARG',
#   'B-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-TIME-ARG',
#   'B-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'O',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.FIRE',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.FIRE',
#   'O',
#   'B-PLACE-ARG',
#   'I-PLACE-ARG',
#   'I-PLACE-ARG',
#   'I-PLACE-ARG',
#   'I-PLACE-ARG',
#   'I-PLACE-ARG',
#   'I-PLACE-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.INDUSTRIAL_ACCIDENT',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.NORMAL_BOMBING',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PLACE-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.VEHICULAR_COLLISION',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.TERRORIST_ATTACK',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-CASUALTIES-ARG',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.FIRE'],
#  ['O',
#   'B-MAGNITUDE-ARG',
#   'I-MAGNITUDE-ARG',
#   'B-NATURAL_EVENT.EARTHQUAKE',
#   'O',
#   'O',
#   'B-PLACE-ARG',
#   'I-PLACE-ARG',
#   'O',
#   'B-NATURAL_EVENT.EARTHQUAKE',
#   'O',
#   'B-MAGNITUDE-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PLACE-ARG',
#   'I-PLACE-ARG',
#   'I-PLACE-ARG',
#   'O',
#   'B-TIME-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-NATURAL_EVENT.EARTHQUAKE',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-DEPTH-ARG',
#   'I-DEPTH-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-NATURAL_EVENT.EARTHQUAKE',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-NATURAL_EVENT.EARTHQUAKE',
#   'O',
#   'O',
#   'O'],
#  ['B-NATURAL_EVENT.EARTHQUAKE',
#   'O',
#   'B-PLACE-ARG',
#   'O',
#   'B-NATURAL_EVENT.EARTHQUAKE',
#   'O',
#   'B-MAGNITUDE-ARG',
#   'O',
#   'B-PLACE-ARG',
#   'I-PLACE-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-NATURAL_EVENT.EARTHQUAKE',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-EPICENTRE-ARG',
#   'I-EPICENTRE-ARG',
#   'I-EPICENTRE-ARG',
#   'I-EPICENTRE-ARG',
#   'I-EPICENTRE-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-NATURAL_EVENT.EARTHQUAKE',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MAGNITUDE-ARG',
#   'I-MAGNITUDE-ARG',
#   'O',
#   'O',
#   'B-NATURAL_EVENT.EARTHQUAKE',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-NATURAL_EVENT.EARTHQUAKE',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-NATURAL_EVENT.FOREST_FIRE',
#   'O',
#   'O',
#   'O',
#   'B-NATURAL_EVENT.EARTHQUAKE',
#   'B-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-NATURAL_EVENT.EARTHQUAKE',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-NATURAL_EVENT.EARTHQUAKE',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-NATURAL_EVENT.DROUGHT',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-TIME-ARG',
#   'I-TIME-ARG',
#   'I-TIME-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-NATURAL_EVENT.FLOODS',
#   'O',
#   'B-NATURAL_EVENT.LAND_SLIDE',
#   'B-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'O',
#   'B-PLACE-ARG',
#   'I-PLACE-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-NATURAL_EVENT.FLOODS',
#   'O',
#   'B-NATURAL_EVENT.LAND_SLIDE',
#   'O',
#   'B-PLACE-ARG',
#   'I-PLACE-ARG',
#   'B-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'O',
#   'B-NATURAL_EVENT.LAND_SLIDE',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-NATURAL_EVENT.FLOODS',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-NATURAL_EVENT.COLD_WAVE',
#   'I-NATURAL_EVENT.COLD_WAVE',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-NATURAL_EVENT.COLD_WAVE',
#   'I-NATURAL_EVENT.COLD_WAVE',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'B-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'O',
#   'B-MAN_MADE_EVENT.ACCIDENTS',
#   'I-MAN_MADE_EVENT.ACCIDENTS',
#   'O',
#   'B-PLACE-ARG',
#   'I-PLACE-ARG',
#   'I-PLACE-ARG',
#   'O',
#   'B-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'O',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.VEHICULAR_COLLISION',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PLACE-ARG',
#   'I-PLACE-ARG',
#   'I-PLACE-ARG',
#   'O',
#   'B-TIME-ARG',
#   'I-TIME-ARG',
#   'I-TIME-ARG',
#   'I-TIME-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.ACCIDENTS',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.ACCIDENTS',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'B-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.ACCIDENTS',
#   'O',
#   'O',
#   'O',
#   'B-PLACE-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.ACCIDENTS',
#   'O',
#   'O',
#   'B-PLACE-ARG',
#   'I-PLACE-ARG',
#   'I-PLACE-ARG',
#   'I-PLACE-ARG',
#   'I-PLACE-ARG',
#   'O',
#   'B-TIME-ARG',
#   'I-TIME-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.VEHICULAR_COLLISION',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.VEHICULAR_COLLISION',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.FIRE',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.ACCIDENTS',
#   'O',
#   'O',
#   'O',
#   'B-TIME-ARG',
#   'O',
#   'B-TIME-ARG',
#   'I-TIME-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.ACCIDENTS',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.VEHICULAR_COLLISION',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-TIME-ARG',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'B-CASUALTIES-ARG',
#   'I-CASUALTIES-ARG',
#   'O',
#   'B-MAN_MADE_EVENT.ACCIDENTS',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MAN_MADE_EVENT.ACCIDENTS',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PLACE-ARG',
#   'I-PLACE-ARG',
#   'I-PLACE-ARG',
#   'I-PLACE-ARG',
#   'I-PLACE-ARG',
#   'O',
#   'B-TIME-ARG',
#   'O',
#   'B-MAN_MADE_EVENT.SHOOT_OUT',
#   'O',
#   'B-TIME-ARG',
#   'I-TIME-ARG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O']]

# %%
from sklearn_crfsuite import scorers
from sklearn_crfsuite import metrics

# %%
labels = list(crf.classes_)
labels.remove('O')
#labels.remove('P')

metrics.flat_f1_score(y_valid, y_pred,
                      average='weighted', labels=labels)
# Out:
# 0.4479497315700026

# %%
# group B and I results
sorted_labels = sorted(
    labels,
    key=lambda name: (name[1:], name[0])
)
print(metrics.flat_classification_report(
    y_valid, y_pred, labels=sorted_labels, digits=3
))
# Out:
#                                       precision    recall  f1-score   support
#
#                  B-AFTER_EFFECTS-ARG      0.500     0.032     0.061        31
#                  I-AFTER_EFFECTS-ARG      1.000     0.021     0.042       283
#                     B-CASUALTIES-ARG      0.635     0.506     0.563       261
#                     I-CASUALTIES-ARG      0.834     0.480     0.609      1514
#                          B-DEPTH-ARG      0.333     0.167     0.222         6
#                          I-DEPTH-ARG      0.800     0.200     0.320        20
#                      B-EPICENTRE-ARG      1.000     0.333     0.500         3
#                      I-EPICENTRE-ARG      1.000     0.160     0.276        25
#                      B-INTENSITY-ARG      1.000     0.500     0.667         6
#                      I-INTENSITY-ARG      0.000     0.000     0.000         4
#                      B-MAGNITUDE-ARG      0.500     0.400     0.444        10
#                      I-MAGNITUDE-ARG      0.333     0.500     0.400         4
#           B-MAN_MADE_EVENT.ACCIDENTS      0.360     0.554     0.437        56
#           I-MAN_MADE_EVENT.ACCIDENTS      0.375     0.562     0.450        16
#     B-MAN_MADE_EVENT.ARMED_CONFLICTS      0.000     0.000     0.000         0
#     I-MAN_MADE_EVENT.ARMED_CONFLICTS      0.000     0.000     0.000         0
#     B-MAN_MADE_EVENT.AVIATION_HAZARD      0.600     0.375     0.462        16
#     I-MAN_MADE_EVENT.AVIATION_HAZARD      0.667     0.500     0.571         4
#               B-MAN_MADE_EVENT.CRIME      0.000     0.000     0.000         6
#               I-MAN_MADE_EVENT.CRIME      0.000     0.000     0.000         3
#                B-MAN_MADE_EVENT.FIRE      0.681     0.734     0.707        64
#                I-MAN_MADE_EVENT.FIRE      0.900     0.529     0.667        17
# B-MAN_MADE_EVENT.INDUSTRIAL_ACCIDENT      0.333     0.083     0.133        12
# I-MAN_MADE_EVENT.INDUSTRIAL_ACCIDENT      0.000     0.000     0.000         1
#       B-MAN_MADE_EVENT.MISCELLANEOUS      0.333     0.100     0.154        10
#       I-MAN_MADE_EVENT.MISCELLANEOUS      0.000     0.000     0.000         0
#      B-MAN_MADE_EVENT.NORMAL_BOMBING      0.238     0.263     0.250        19
#      I-MAN_MADE_EVENT.NORMAL_BOMBING      0.222     0.400     0.286         5
#               B-MAN_MADE_EVENT.RIOTS      0.000     0.000     0.000         5
#           B-MAN_MADE_EVENT.SHOOT_OUT      0.643     0.818     0.720        11
#           I-MAN_MADE_EVENT.SHOOT_OUT      1.000     1.000     1.000         1
#      B-MAN_MADE_EVENT.SUICIDE_ATTACK      0.429     0.200     0.273        15
#      I-MAN_MADE_EVENT.SUICIDE_ATTACK      0.500     0.083     0.143        12
#    B-MAN_MADE_EVENT.SURGICAL_STRIKES      0.625     0.385     0.476        13
#    I-MAN_MADE_EVENT.SURGICAL_STRIKES      1.000     0.667     0.800         6
#    B-MAN_MADE_EVENT.TERRORIST_ATTACK      0.000     0.000     0.000         1
#    I-MAN_MADE_EVENT.TERRORIST_ATTACK      0.000     0.000     0.000         0
#     B-MAN_MADE_EVENT.TRAIN_COLLISION      0.286     0.105     0.154        19
#     I-MAN_MADE_EVENT.TRAIN_COLLISION      0.000     0.000     0.000         1
#   B-MAN_MADE_EVENT.TRANSPORT_HAZARDS      0.273     0.125     0.171        24
#   I-MAN_MADE_EVENT.TRANSPORT_HAZARDS      0.286     0.200     0.235        10
# B-MAN_MADE_EVENT.VEHICULAR_COLLISION      0.500     0.435     0.466        62
# I-MAN_MADE_EVENT.VEHICULAR_COLLISION      0.500     0.154     0.235        13
#                           B-NAME-ARG      1.000     0.250     0.400        16
#                           I-NAME-ARG      0.000     0.000     0.000         2
#           B-NATURAL_EVENT.AVALANCHES      1.000     1.000     1.000         4
#             B-NATURAL_EVENT.BLIZZARD      0.000     0.000     0.000         0
#            B-NATURAL_EVENT.COLD_WAVE      0.667     1.000     0.800         2
#            I-NATURAL_EVENT.COLD_WAVE      0.667     1.000     0.800         2
#              B-NATURAL_EVENT.CYCLONE      1.000     0.600     0.750         5
#              I-NATURAL_EVENT.CYCLONE      0.000     0.000     0.000         0
#              B-NATURAL_EVENT.DROUGHT      1.000     0.200     0.333         5
#           B-NATURAL_EVENT.EARTHQUAKE      0.968     0.857     0.909        35
#           I-NATURAL_EVENT.EARTHQUAKE      0.000     0.000     0.000         0
#             B-NATURAL_EVENT.EPIDEMIC      0.000     0.000     0.000         0
#             I-NATURAL_EVENT.EPIDEMIC      0.000     0.000     0.000         0
#               B-NATURAL_EVENT.FLOODS      0.727     0.727     0.727        11
#               I-NATURAL_EVENT.FLOODS      0.000     0.000     0.000         0
#          B-NATURAL_EVENT.FOREST_FIRE      0.250     0.071     0.111        14
#          I-NATURAL_EVENT.FOREST_FIRE      1.000     0.333     0.500         3
#          B-NATURAL_EVENT.HAIL_STORMS      0.000     0.000     0.000         0
#          I-NATURAL_EVENT.HAIL_STORMS      0.000     0.000     0.000         0
#            B-NATURAL_EVENT.HEAT_WAVE      0.000     0.000     0.000         0
#            I-NATURAL_EVENT.HEAT_WAVE      0.000     0.000     0.000         0
#       B-NATURAL_EVENT.HEAVY_RAINFALL      0.000     0.000     0.000         0
#       I-NATURAL_EVENT.HEAVY_RAINFALL      0.000     0.000     0.000         0
#            B-NATURAL_EVENT.HURRICANE      0.750     0.150     0.250        20
#           B-NATURAL_EVENT.LAND_SLIDE      1.000     0.900     0.947        10
#           I-NATURAL_EVENT.LAND_SLIDE      0.000     0.000     0.000         0
#    B-NATURAL_EVENT.LIMNIC_ERRUPTIONS      0.000     0.000     0.000         1
#            B-NATURAL_EVENT.ROCK_FALL      0.000     0.000     0.000         1
#            I-NATURAL_EVENT.ROCK_FALL      0.000     0.000     0.000         1
#                B-NATURAL_EVENT.STORM      0.826     0.905     0.864        21
#                I-NATURAL_EVENT.STORM      0.000     0.000     0.000         0
#              B-NATURAL_EVENT.TORNADO      0.833     1.000     0.909         5
#              B-NATURAL_EVENT.TSUNAMI      0.000     0.000     0.000         1
#              I-NATURAL_EVENT.TSUNAMI      0.000     0.000     0.000         0
#              B-NATURAL_EVENT.VOLCANO      0.000     0.000     0.000         6
#              I-NATURAL_EVENT.VOLCANO      0.000     0.000     0.000         0
#                    B-PARTICIPANT-ARG      0.667     0.061     0.111        33
#                    I-PARTICIPANT-ARG      1.000     0.013     0.026        75
#                          B-PLACE-ARG      0.513     0.367     0.428       218
#                          I-PLACE-ARG      0.724     0.328     0.451       537
#                         B-REASON-ARG      0.438     0.143     0.215        49
#                         I-REASON-ARG      0.679     0.055     0.102       343
#                          B-SPEED-ARG      1.000     0.286     0.444         7
#                          I-SPEED-ARG      0.000     0.000     0.000        10
#                    B-TEMPERATURE-ARG      0.000     0.000     0.000         0
#                    I-TEMPERATURE-ARG      0.000     0.000     0.000         0
#                           B-TIME-ARG      0.642     0.547     0.591       128
#                           I-TIME-ARG      0.671     0.482     0.561       114
#                           B-TYPE-ARG      1.000     0.429     0.600         7
#                           I-TYPE-ARG      1.000     0.200     0.333         5
#
#                            micro avg      0.696     0.365     0.479      4280
#                            macro avg      0.416     0.252     0.280      4280
#                         weighted avg      0.733     0.365     0.448      4280

# %%
df_test = pd.read_json("./data/processed/en/test.json", orient="records", lines=True)

# %%
import xml.etree.ElementTree as ET
from utils import get_entity_info

# %%
entity_info = get_entity_info(y_pred[0], df_valid.iloc[0]["tokens"])
entity_info
# Out:
# [{'tokens': ['5', 'children', 'killed'],
#   'label': 'CASUALTIES-ARG',
#   'start': 3,
#   'end': 6,
#   'entity_phrase': ' 5   children   killed '},
#  {'tokens': ['Balochistan'],
#   'label': 'PLACE-ARG',
#   'start': 7,
#   'end': 8,
#   'entity_phrase': ' Balochistan '},
#  {'tokens': ['landslide'],
#   'label': 'NATURAL_EVENT.LAND_SLIDE',
#   'start': 8,
#   'end': 9,
#   'entity_phrase': ' landslide '},
#  {'tokens': ['A',
#    'woman',
#    'and',
#    'her',
#    'five',
#    'children',
#    'lost',
#    'their',
#    'lives'],
#   'label': 'CASUALTIES-ARG',
#   'start': 9,
#   'end': 18,
#   'entity_phrase': ' A   woman   and   her   five   children   lost   their   lives '},
#  {'tokens': ['landslide'],
#   'label': 'NATURAL_EVENT.LAND_SLIDE',
#   'start': 20,
#   'end': 21,
#   'entity_phrase': ' landslide '},
#  {'tokens': ['Harnai', 'town', 'of', 'Balochistan'],
#   'label': 'PLACE-ARG',
#   'start': 22,
#   'end': 26,
#   'entity_phrase': ' Harnai   town   of   Balochistan '},
#  {'tokens': ['Sunday', 'night.'],
#   'label': 'TIME-ARG',
#   'start': 27,
#   'end': 29,
#   'entity_phrase': ' Sunday   night. '},
#  {'tokens': ['landslide'],
#   'label': 'NATURAL_EVENT.LAND_SLIDE',
#   'start': 54,
#   'end': 55,
#   'entity_phrase': ' landslide '},
#  {'tokens': ['fell'],
#   'label': 'MAN_MADE_EVENT.MISCELLANEOUS',
#   'start': 69,
#   'end': 70,
#   'entity_phrase': ' fell '},
#  {'tokens': ['killed', 'a', 'woman', 'and', 'her', 'five', 'children.'],
#   'label': 'CASUALTIES-ARG',
#   'start': 74,
#   'end': 81,
#   'entity_phrase': ' killed   a   woman   and   her   five   children. '},
#  {'tokens': ['incident'],
#   'label': 'MAN_MADE_EVENT.FIRE',
#   'start': 83,
#   'end': 84,
#   'entity_phrase': ' incident '}]

# %%
def generate_xml(entity_info, docid, simple=False):
    root = ET.Element("DOCUMENT") 
    docid_e = ET.Element("DOCID")
    docid_e.text = f"{docid}"
    root.append(docid_e) 
    for info in entity_info:
        label = info["label"]
        subtype = None
        if label.startswith(tuple(CLASS_MAP.keys())):
            label, subtype = label.split(".")
            label = CLASS_MAP[label]
        elif simple:
            continue
        if label.endswith("-ARG"):
            label = label.split("-ARG")[0]
            subtype = None
        elem = ET.Element(label.upper())
        if subtype:
            elem.attrib["TYPE"] = subtype.upper()
        elem.text = info["entity_phrase"]
        root.append(elem)
    return root

# %%
root = generate_xml(entity_info, 124, simple=True)

# %%
ET.tostring(root)
# Out:
# b'<DOCUMENT><DOCID>124</DOCID><NATURAL_EVENT TYPE="LAND_SLIDE"> landslide </NATURAL_EVENT><NATURAL_EVENT TYPE="LAND_SLIDE"> landslide </NATURAL_EVENT><NATURAL_EVENT TYPE="LAND_SLIDE"> landslide </NATURAL_EVENT><MAN_MADE_EVENT TYPE="MISCELLANEOUS"> fell </MAN_MADE_EVENT><MAN_MADE_EVENT TYPE="FIRE"> incident </MAN_MADE_EVENT></DOCUMENT>'

# %%
X_test, y_test = df_to_Xy(df_test)

# %%
y_pred = crf.predict(X_test)

# %%
from pathlib import Path

# %%
base_path = Path(f"./data/3Idiots/")
def create_files(df_test, lang):
    X_test, y_test = df_to_Xy(df_test)
    y_pred = crf.predict(X_test)
    for pred, (idx, row) in zip(y_pred, df_test.iterrows()):
        entity_info = get_entity_info(pred, row["tokens"])
        docid = row["docid"]
        for task, simple in enumerate([True, False], start=1):
            root = generate_xml(entity_info, docid, simple=simple)
            tree = ET.ElementTree(root) 
            out_path = base_path / f"Task_{task}"/ lang / f"{docid}.xml"
            #with open(out_path, "w+") as fp:
            tree.write(out_path, encoding="utf-8")

# %%
lang = "en"
create_files(df_test, lang)

# %%
for lang in ["en", "bn", "tm", "ma", "hn"]:
    for task in range(1,3):
        out_path = base_path / f"Task_{task}"/ lang
        out_path.mkdir(exist_ok=True)

# %%
["en", "bn", "tm", "ma", "hn"][:2]
# Out:
# ['en', 'bn']

# %%
for lang in ["en", "bn", "tm", "ma", "hn"]:
    print(lang)
    df_train = pd.read_json(f"./data/processed/{lang}/train.json", orient="records", lines=True)
    X_train, y_train = df_to_Xy(df_train)
    print(df_train.shape)
    crf = sklearn_crfsuite.CRF(algorithm='ap', max_iterations=100, all_possible_transitions=False)
    print("Training")
    # %time crf.fit(X_train, y_train)
    df_test = pd.read_json(f"./data/processed/{lang}/test.json", orient="records", lines=True)
    print("Writing")
    create_files(df_test, lang)
# Out:
# en
# (828, 4)
# Training
# Wall time: 4min 16s
# Writing
# bn
# (800, 4)
# Training
# Wall time: 4min 4s
# Writing
